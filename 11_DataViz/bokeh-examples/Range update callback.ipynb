# %%
from __future__ import division

import numpy as np

from bokeh.models import ColumnDataSource, CustomJS, Rect
from bokeh.plotting import output_notebook, figure, show
from bokeh.layouts import row

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="282cf9ea-1a7c-4011-a901-228103fb0983">Loading BokehJS ...</span>
#     </div>

# %%
N = 20
img = np.empty((N,N), dtype=np.uint32)
view = img.view(dtype=np.uint8).reshape((N, N, 4))
for i in range(N):
    for j in range(N):
        view[i, j, 0] = int(i/N*255)
        view[i, j, 1] = 158
        view[i, j, 2] = int(j/N*255)
        view[i, j, 3] = 255

# %%
source = ColumnDataSource({'x':[], 'y':[], 'width':[], 'height':[]})

# %%
xrange_callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var start = cb_obj.start;
    var end = cb_obj.end;
    data['x'] = [start + (end - start) / 2];
    data['width'] = [end - start];
    source.trigger('change');
""")

yrange_callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var start = cb_obj.start;
    var end = cb_obj.end;
    data['y'] = [start + (end - start) / 2];
    data['height'] = [end - start];
    source.trigger('change');
""")

# %%
p1 = figure(title='Box Zoom Here', plot_width=400, plot_height=400,
            x_range=(0,10), y_range=(0,10), tools ='box_zoom,wheel_zoom,pan,reset')
p1.image_rgba(image=[img], x=[0], y=[0], dw=[10], dh=[10])
p1.x_range.callback = xrange_callback
p1.y_range.callback = yrange_callback

p2 = figure(title='See Zoom Window Here', plot_width=400, plot_height=400, 
            x_range=(0,10), y_range=(0,10), tools="")
p2.image_rgba(image=[img], x=[0], y=[0], dw=[10], dh=[10])
rect = Rect(x='x', y='y', width='width', height='height', fill_alpha=0, line_color='black')
p2.add_glyph(source, rect)
# Out:
# GlyphRenderer(id='04f27331-5958-4917-99ee-8aeee0d88c73', ...)

# %%
show(row(p1, p2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c0a59c78-8c79-4dac-a6d9-165a7f58b73d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c0a59c78-8c79-4dac-a6d9-165a7f58b73d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0a59c78-8c79-4dac-a6d9-165a7f58b73d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0a59c78-8c79-4dac-a6d9-165a7f58b73d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b3ee14e4-c183-484b-a24f-4f75425cf4f3":{"roots":{"references":[{"attributes":{"data_source":{"id":"b8a1b52d-ee6d-4a8c-9e2b-0fcb35f3e4d4","type":"ColumnDataSource"},"glyph":{"id":"780eb100-610e-414f-9fa1-dce782b76f65","type":"ImageRGBA"},"hover_glyph":null,"nonselection_glyph":{"id":"bbac73b1-edee-4ccd-8b34-6f6e6abde43c","type":"ImageRGBA"},"selection_glyph":null},"id":"d45c0db0-a6b3-4ee5-9d6d-888ae50c2e0e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["image","x","y","dw","dh"],"data":{"dh":[10],"dw":[10],"image":[{"__ndarray__":"...","dtype":"uint32","shape":[20,20]}],"x":[0],"y":[0]}},"id":"b8a1b52d-ee6d-4a8c-9e2b-0fcb35f3e4d4","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"22722dd4-64be-443f-a5c8-2b9d5da24be5","type":"LinearAxis"}],"left":[{"id":"4ab512d6-2e7f-4399-96f7-af5adf48cb66","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"22722dd4-64be-443f-a5c8-2b9d5da24be5","type":"LinearAxis"},{"id":"90d17ec9-7f63-4a7e-bbe5-97400d261f74","type":"Grid"},{"id":"4ab512d6-2e7f-4399-96f7-af5adf48cb66","type":"LinearAxis"},{"id":"7bb1225e-8961-40f2-bb6b-7c6333f8853f","type":"Grid"},{"id":"65eab948-2fc2-4017-8bca-90ac2c78d0a1","type":"BoxAnnotation"},{"id":"d45c0db0-a6b3-4ee5-9d6d-888ae50c2e0e","type":"GlyphRenderer"}],"title":{"id":"110f92f8-f06d-45f2-80f1-02db1253bc4a","type":"Title"},"tool_events":{"id":"d6f2f161-dbfc-4a50-9951-051d49d27fd5","type":"ToolEvents"},"toolbar":{"id":"386fd3b6-a11a-4eae-ab00-d7e098792679","type":"Toolbar"},"x_range":{"id":"2f55b3a9-d7a9-4139-8454-7b72df5cbaa7","type":"Range1d"},"y_range":{"id":"0f49d008-bf2c-440c-9c82-02aa219aa41d","type":"Range1d"}},"id":"02aae3c1-f732-49cd-aa58-09ef674c2781","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"Box Zoom Here"},"id":"110f92f8-f06d-45f2-80f1-02db1253bc4a","type":"Title"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bbac73b1-edee-4ccd-8b34-6f6e6abde43c","type":"ImageRGBA"},{"attributes":{},"id":"2983b912-1ad3-4a0c-929c-94d82cef1527","type":"BasicTicker"},{"attributes":{"args":{"source":{"id":"3211f92d-3deb-452e-a174-567a2e75373a","type":"ColumnDataSource"}},"code":"\n    var data = source.data;\n    var start = cb_obj.start;\n    var end = cb_obj.end;\n    data['x'] = [start + (end - start) / 2];\n    data['width'] = [end - start];\n    source.trigger('change');\n"},"id":"035cb073-fefb-4b52-8083-a950a95156ff","type":"CustomJS"},{"attributes":{},"id":"d6f2f161-dbfc-4a50-9951-051d49d27fd5","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"71ac63de-6e9f-4305-9607-1beb76f74076","type":"BoxZoomTool"},{"id":"e3be2edb-4e68-4466-a4dd-9533d92ca8cf","type":"WheelZoomTool"},{"id":"39b40af0-6f55-40a8-a121-1d403e6bfca6","type":"PanTool"},{"id":"55768dc8-a149-417e-b729-354514979ec5","type":"ResetTool"}]},"id":"386fd3b6-a11a-4eae-ab00-d7e098792679","type":"Toolbar"},{"attributes":{"args":{"source":{"id":"3211f92d-3deb-452e-a174-567a2e75373a","type":"ColumnDataSource"}},"code":"\n    var data = source.data;\n    var start = cb_obj.start;\n    var end = cb_obj.end;\n    data['y'] = [start + (end - start) / 2];\n    data['height'] = [end - start];\n    source.trigger('change');\n"},"id":"12ec7ef7-0802-4295-9e39-e3dd85ce5d28","type":"CustomJS"},{"attributes":{"fill_alpha":{"value":0},"height":{"field":"height","units":"data"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"79fe1c3d-8fc4-410f-8f41-148135e3d717","type":"Rect"},{"attributes":{},"id":"ebcce48c-9988-43a0-9071-10e241258cef","type":"BasicTicker"},{"attributes":{"plot":{"id":"02aae3c1-f732-49cd-aa58-09ef674c2781","subtype":"Figure","type":"Plot"},"ticker":{"id":"2983b912-1ad3-4a0c-929c-94d82cef1527","type":"BasicTicker"}},"id":"90d17ec9-7f63-4a7e-bbe5-97400d261f74","type":"Grid"},{"attributes":{"format ...
